# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or strings and expressions will be mathematical operators.

# %% [markdown]
# Ans:
# - '*' 		-------- Expression
# - 'hello'	-------- Values
# - -87.8		-------- Values
# - '-' 		  -------- Expression
# - / 		  -------- Expression
# - '+'	      -------- Expression
# - 6 		  -------- Values

# %% [markdown]
# 2. What is the difference between string and variable?

# %% [markdown]
# Ans:
# 1.   Variable:
# - It is a identifier to store a value in a memory location and to manipulate it if needed.
# -  It is a entity or container where we store a data which we can process in the run-time.
# - When we write 'a', then inside the memory it is going to reserve a space. It is the RAM/ main memory. 10 is a data which is stored in memory, whose reference is given to 'a'. 'a' is a local variable.
# - e.g.
# ```
#   a=10
#   b=20
#   print(a+b)  ## prints 30
# ```
# 2.   Strings:
# - String is a datatype for a sequence of characters
# - Anything you assign to a variable using quotes (single or double) will be considered as a string.
# - e.g.
# ```
# a='10'
# b='20'
# print(a+b)  ## 1020
# ```
#
#  In summary, a variable is a container that holds data, while a string is a specific type of data that can be held by a variable.

# %% [markdown]
# 3. Describe three different data types.

# %% [markdown]
# Datatypes in Python:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Numeric Datatype:
# - numeric data type represent the data which has numeric value. Numeric value can be integer, floating number or even complex numbers. These values are defined as int, float and complex class in Python.
# 2. Sequence Datatypes:
# - sequence is the ordered collection of similar or different data types. Sequences allows to store multiple values in an organized and efficient fashion. There are several sequence types in Python –
#
# > String: A string is a collection of one or more characters put in a single quote, double-quote or triple quote.
#
# > List: These are ordered collection of data. It is very flexible as the items in a list do not need to be of the same type. It can be created by just placing the sequence inside the square brackets[ ].
#
# > Tuple: Just like list, tuple is also an ordered collection of Python objects. The only difference between tuple and list is that tuples are immutable i.e. tuples cannot be modified after it is created.
#
# 3. Set Datatypes:
# - Set is an unordered collection of data type that is iterable, mutable and has no duplicate elements. The order of elements in a set is undefined though it may consist of various elements.
#
# 4. Dictionary Datatype:
# - Dictionary in Python is an unordered collection of data values, used to store data values like a map, which unlike other Data Types that hold only single value as an element, Dictionary holds key:value pair. Key-value is provided in the dictionary to make it more optimized. Each key-value pair in a Dictionary is separated by a colon :, whereas each key is separated by a ‘comma’.
#
# 5. Boolean Datatype:
# - Data type with one of the two built-in values, True or False. Boolean objects that are equal results in True, and those which are not equal results in False.

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# Ans: An expression is a combination of operators and operands that is interpreted to produce some other value. An expression is evaluated as per the precedence of its operators. So that if there is more than one operator in an expression, their precedence decides which operation will be performed first.
# Different types of expressions:
# 1. Constant Expressions: These are the expressions that have constant values only.
# ```
# x=3+8
# ```
# 2. Arithmetic Expressions: An arithmetic expression is a combination of numeric values, operators, and sometimes parenthesis. The result of this type of expression is also a numeric value.
# ```
# x=4
# y=2
# print(x/y)
# ```
# 3. Integral Expressions: These are the kind of expressions that produce only integer results after all computations and type conversions.
# ```
# a = 13
# b = 12.0
# c = a + int(b)
# print(c)
# ```
# 4. Floating Expressions: These are the kind of expressions which produce floating point numbers as result after all computations and type conversions.
# ```
# a = 13
# b = 5
# c = a / b
# print(c)
# ```
# 5. Relational Expressions: In these types of expressions, arithmetic expressions are written on both sides of relational operator (> , < , >= , <=). Those arithmetic expressions are evaluated first, and then compared as per relational operator and produce a boolean output in the end.
# ```
# a = 21
# b = 13
# c = 40
# d = 37
# p = (a + b) >= (c - d)
# print(p)
# ```
# 6. Logical Expressions: These are kinds of expressions that result in either True or False. It basically specifies one or more conditions.
# ```
# P = (10 == 9)
# Q = (7 > 5)
# R = P and Q
# S = P or Q
# T = not P
# ```
# 7. Bitwise Expressions: These are the kind of expressions in which computations are performed at bit level.
# ```
# a = 12
# x = a >> 2
# y = a << 1
# print(x, y)
# Output
# 3 24
# ```
#
# 8. Combinational Expressions: We can also use different types of expressions in a single expression, and that will be termed as combinational expressions.
# ```
# a = 16
# b = 12
# c = a + (b >> 1)
# print(c)
# ```

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# Ans:
# - A statement performs certain action (does something), an expression evaluates to a value. All the expressions can be counted as statement, since they are performing certain actions.
# - The key difference between an expression and a statement is that an expression is evaluated to produce a value, while a statement performs an action.
# - If you can print it, or assign it to a variable, it’s an expression. If you can’t, it’s a statement.
#
# Here are some examples of expressions:
# ```
# 2 + 2
# 3 * 7
# 1 + 2 + 3 * (8 ** 9) - sqrt(4.0)
# min(2, 22)
# max(3, 94)
# round(81.5)
# "foo"
# "bar"
# "foo" + "bar"
# None
# True
# False
# 2
# 3
# 4.0
# ```
# All of the above can be printed or assigned to a variable.
#
# Here are some examples of statements:
# ```
# if CONDITION:
# elif CONDITION:
# else:
# for VARIABLE in SEQUENCE:
# while CONDITION:
# try:
# except EXCEPTION as e:
# class MYCLASS:
# def MYFUNCTION():
# return SOMETHING
# raise SOMETHING
# with SOMETHING:
# ```
# None of the above constructs can be assigned to a variable. They are syntactic elements that serve a purpose, but do not themselves have any intrinsic “value”. In other words, these constructs don’t “evaluate” to anything.
#
#
# eg.
#
# > x = 1 # a statement
#
# > y = x + 1 # an expression
#
# > print(y) # a statement

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# ```
# bacon = 22
# bacon + 1
# ```

# %%
bacon = 22
bacon + 1
print(f"Value of variable bacon is: {bacon}")
# Out:
# Value of variable bacon is: 22

# %% [markdown]
# 7. What should the values of the following two terms be?
# ```
# 'spam' + 'spamspam'
# 'spam' * 3
# ```

# %%
var1='spam' + 'spamspam'
print(var1)
# Out:
# spamspamspam

# %%
var2='spam' * 3
print(var2)
# Out:
# spamspamspam

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# Ans:
# eggs=10 is a valid variable name where as 100='subbu' is invalid because it causes "syntax error" as variable name cannot start with a number.
#
# Rules for creating variables in Python:
# - A variable name must start with a letter or the underscore character.
# - A variable name cannot start with a number.
# - A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ ).
# - Variable names are case-sensitive (name, Name and NAME are three different variables).
# - The reserved words(keywords) cannot be used naming the variable.

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %%
value=2022
int_version=int(value)
float_version=float(value)
string_version=str(value)

print(f"The integer: {int_version}, floating-point: {float_version}, and string version: {string_version}")
# Out:
# The integer: 2022, floating-point: 2022.0, and string version: 2022

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# ```
# 'I have eaten ' + 99 + ' burritos.'
# ```
# This expression will result in TypeError. "TypeError: can only concatenate str (not "int") to str"
#
# To fix the problem: Updated statement is as follows
# ```
# 'I have eaten ' + '99' + ' burritos.'
# ```
#
# Output: I have eaten 99 burritos.
